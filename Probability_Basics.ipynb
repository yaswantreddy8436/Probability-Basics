# %% [markdown]
# 1) Total outcomes \(n(S) = 6\).
# (a) Even number
#  Die outcomes are \(\{1, 2, 3, 4, 5, 6\}\).
#  P(even)=63​=21​
#
#  (b) Number greater than 4
#  Numbers greater than 4 = {5, 6} → 2 outcomes
#  P(>4)=62​=31​
#
# 2) Using the addition rule:
# P(M∪S)=
# 50
# 20+15−5
# 	​=30/50​=3/5​=0.6
#
# 3) Total balls = 3 red + 2 blue = 5
# Probability first ball is red:
#
# P(red)=3/5
#
# 4) Use Stratified Sampling.
# Because the population has: 60% boys and 40% girls
# Stratified sampling ensures both groups are represented in the same proportion in the sample.
#
# 5) Sampling error: xˉ−μ
# Sampling error : 158-160 = -2
#
# 6) Standard Error of Mean (SEM):
# =5000/10= 500
#
# 7) Students liking at least one sport:
# P(C∪F)=60/100= 0.6
#
# 8) Probability both drawn cards are Aces:
# First Ace:4/52
# Second Ace:3/51
#
# P=4/52*3/51 =1/221
#
# 9) Non-defective probability for one bulb:
# 1−0.02=0.98
# For 5 bulbs: (0.98)5=0.904
#
# 10) Discrete Random Variable
# Examples:
# Number of students in a class
# Number of cars in a parking lot
#
# Continuous Random Variable
# Takes any value within a range.
#
# Examples:Height of students
# Temperature
# Weight of a person
